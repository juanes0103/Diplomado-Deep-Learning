# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import glob
import re
import h5py
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline
from sklearn.model_selection import train_test_split 
import pandas as pd
from tensorflow.keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers import LeakyReLU
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras import regularizers
np.set_printoptions(precision=3, suppress=True) #Make numpy easier to read

# %%
os.chdir("/content/drive/My Drive/DeplomadoDeepLearning/Gomez_Saul/Proyecto/")

# %%
ls
# Out:
# 'Copia de Copia de ImageClasification_algorithm (1).ipynb'
# 'Copia de Copia de ImageClasification_algorithm.ipynb'
# 'Copia de ImageClasification_algorithm (1).ipynb'
# 'Copia de ImageClasification_algorithm (2).ipynb'
# 'Copia de ImageClasification_algorithm.ipynb'
#  DataAugmentationOneClass.ipynb
#  DataBase/
#  ImageClasification_algorithm.ipynb
#  ImageSplitManyClasses.ipynb
#  OriginalDataBase/

# %%
train_path = "//content/drive/My Drive/DeplomadoDeepLearning/Gomez_Saul/Proyecto/DataBase/train"
validation_path = "//content/drive/My Drive/DeplomadoDeepLearning/Gomez_Saul/Proyecto/DataBase/validation"

# %%
def trainFileCount(train_path):
  total_file_training= 0;
  basename ='';
  for root, dirnames, filenames in os.walk(train_path):
    for dirname in dirnames:
      directory_training = os.path.join(train_path, dirname) 
      directory_training = directory_training + os.sep
      num_file_training = len(os.listdir(directory_training))
      total_file_training = total_file_training + num_file_training
      basename = os.path.basename(train_path)
      print('total',basename, dirname,' images:',num_file_training)
  print('Total', basename,' images:',total_file_training)
  print('-------------------------------------------------------')

# %%
total_train_img = trainFileCount(train_path)
total_Validation_img = trainFileCount(validation_path)
# Out:
# total train Ptosis  images: 1054
# total train Ectropion  images: 482
# total train Chalazion  images: 218
# total train Triquiasis  images: 163
# total train TumorParpado  images: 368
# total train BlefaroChalasis  images: 581
# total train Blefaritis  images: 132
# total train Xanthelasma  images: 184
# Total train  images: 3182
# -------------------------------------------------------
# total validation Ptosis  images: 264
# total validation Ectropion  images: 121
# total validation Chalazion  images: 55
# total validation Triquiasis  images: 41
# total validation TumorParpado  images: 92
# total validation BlefaroChalasis  images: 146
# total validation Blefaritis  images: 33
# total validation Xanthelasma  images: 46
# Total validation  images: 798
# -------------------------------------------------------

# %%
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
img = cv2.imread('/content/drive/My Drive/DeplomadoDeepLearning/Gomez_Saul/Proyecto/DataBase/train/Blefaritis/1.png')
img.shape
# Out:
# (164, 164, 3)

# %%
batch_size = 32
epochs = 50
IMG_SHAPE = 164

# %%
image_generator_train = ImageDataGenerator(
                    rescale=1./255, 
                    rotation_range=15,
                    width_shift_range=.005, 
                    height_shift_range=.005, 
                    horizontal_flip=True, 
                    zoom_range=0.3
                    )

# %%
image_generator_validation = ImageDataGenerator(
                    rescale=1./255, 
                    rotation_range=20, 
                    width_shift_range=.01, 
                    height_shift_range=.01, 
                    horizontal_flip=True, 
                    zoom_range=0.3
                    )

# %%
train_data_generator = image_generator_train.flow_from_directory(
                                                batch_size=batch_size, 
                                                directory=train_path, 
                                                shuffle=True, 
                                                target_size=(IMG_SHAPE,IMG_SHAPE),
                                                class_mode='binary'
                                                )
# Out:
# Found 3182 images belonging to 8 classes.

# %%
Validation_data_generator = image_generator_validation.flow_from_directory(
                                                batch_size=batch_size, 
                                                directory=validation_path, 
                                                shuffle=False, 
                                                target_size=(IMG_SHAPE,IMG_SHAPE),
                                                class_mode='binary'
                                                )
# Out:
# Found 798 images belonging to 8 classes.

# %%
augmented_images = [train_data_generator[0][0][1] for i in range(5)]

# %%
sample_training_images, _ = next(train_data_generator) 
sample_training_images.shape
# Out:
# (32, 164, 164, 3)

# %%
plotImages(augmented_images[:5])

# %%
# Herramienta para ver el comportamiento del entrenamiento
def plot_train_performance(train_data):
    acc = train_data.history['accuracy']
    val_acc = train_data.history['val_accuracy']
    loss = train_data.history['loss']
    val_loss = train_data.history['val_loss']

    epochs = range(1,len(acc)+1)

    plt.plot(epochs, acc, 'b', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.figure()
    plt.plot(epochs, loss, 'b', label='Training Loss')
    plt.plot(epochs, val_loss, 'r', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    plt.show()

# %%
# Funcion para comparar las predicciónes
import numpy as np
def show_pred(test_ds):
    to_predict_data = test_ds.batch(1).take(9)
    results = np.argmax(model.predict(to_predict_data),axis=1)

    import matplotlib.pyplot as plt # A continuación se muestra un ejemplo con su etiqueta
    fig = plt.figure(figsize=(20,20))
    for i, (image, label) in enumerate(to_predict_data):
      res_plt = fig.add_subplot(3, 3, i+1)
      res_plt.set_title(classes_dict[int(np.squeeze(label.numpy()))])
      predicted_lbl = "Predicted: " + classes_dict[results[i]]
      res_plt.set_xlabel(predicted_lbl)
      plt.imshow(np.squeeze(image.numpy()*255).astype(np.uint8))
    plt.show()

# %%
from tensorflow import keras
from tensorflow.keras.applications.vgg16 import VGG16, decode_predictions 

HEIGHT, WIDTH, CHANNELS = (164,164,3) # el tamaño de las imagenes
input_t = keras.Input(shape=(HEIGHT, WIDTH, CHANNELS)) 
transfer_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_t) # no se incluyen las redes neuronales del final de la aqruitectura

transfer_model.trainable = False # Se congelan los pesos de la arquitectura usada como 
transfer_model.summary() # Se observa la arqutiectura para decidir donnde tomar las caracteristicas
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 164, 164, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 164, 164, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 164, 164, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 82, 82, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 82, 82, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 82, 82, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 41, 41, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 41, 41, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 41, 41, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 41, 41, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 20, 20, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 20, 20, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 10, 10, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 5, 5, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D

middle = transfer_model.get_layer('block3_pool')
newmodel = Model(inputs = input_t, outputs=middle.output)

#create model
model = Sequential()
#add model layers
model.add(newmodel)
model.add(Conv2D(512, 5, padding='same', activation='relu')) 
model.add(Conv2D(512, 4, padding='same', activation='relu')) 
model.add(Conv2D(512, 5, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) 
model.add(Conv2D(1024, 4, padding='same', activation='relu')) 
model.add(Conv2D(1024, 5, padding='same', activation='relu', )) 
model.add(Conv2D(1024, 4, padding='same', activation='relu', ))
model.add(MaxPooling2D(pool_size=(2, 2))) 


model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(100, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# functional_1 (Functional)    (None, 20, 20, 256)       1735488
# _________________________________________________________________
# conv2d (Conv2D)              (None, 20, 20, 512)       3277312
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 20, 512)       4194816
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 512)       6554112
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 512)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 1024)      8389632
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 1024)      26215424
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 10, 10, 1024)      16778240
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 1024)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 25600)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              26215424
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               25700
# =================================================================
# Total params: 94,304,932
# Trainable params: 92,569,444
# Non-trainable params: 1,735,488
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
resume = model.fit(train_data_generator, 
                   validation_data=Validation_data_generator,
                   epochs=epochs)
model.save('my_model.h5')
# Out:
# Epoch 1/50
# 100/100 [==============================] - 492s 5s/step - loss: 2.0050 - accuracy: 0.3451 - val_loss: 1.6195 - val_accuracy: 0.4223
# Epoch 2/50
# 100/100 [==============================] - 35s 345ms/step - loss: 1.5454 - accuracy: 0.4422 - val_loss: 1.5292 - val_accuracy: 0.4211
# Epoch 3/50
# 100/100 [==============================] - 34s 343ms/step - loss: 1.3197 - accuracy: 0.5195 - val_loss: 1.5005 - val_accuracy: 0.4812
# Epoch 4/50
# 100/100 [==============================] - 34s 344ms/step - loss: 1.1749 - accuracy: 0.5676 - val_loss: 1.3688 - val_accuracy: 0.5388
# Epoch 5/50
# 100/100 [==============================] - 34s 343ms/step - loss: 1.1042 - accuracy: 0.6018 - val_loss: 1.3862 - val_accuracy: 0.5276
# Epoch 6/50
# 100/100 [==============================] - 34s 344ms/step - loss: 1.0450 - accuracy: 0.6314 - val_loss: 1.3618 - val_accuracy: 0.5576
# Epoch 7/50
# 100/100 [==============================] - 34s 343ms/step - loss: 1.0004 - accuracy: 0.6345 - val_loss: 1.2185 - val_accuracy: 0.6003
# Epoch 8/50
# 100/100 [==============================] - 35s 347ms/step - loss: 0.9194 - accuracy: 0.6785 - val_loss: 1.2768 - val_accuracy: 0.5652
# Epoch 9/50
# 100/100 [==============================] - 35s 346ms/step - loss: 0.9020 - accuracy: 0.6700 - val_loss: 1.2930 - val_accuracy: 0.5789
# Epoch 10/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.8701 - accuracy: 0.6864 - val_loss: 1.1816 - val_accuracy: 0.5952
# Epoch 11/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.7832 - accuracy: 0.7172 - val_loss: 1.2019 - val_accuracy: 0.6228
# Epoch 12/50
# 100/100 [==============================] - 34s 343ms/step - loss: 0.7803 - accuracy: 0.7172 - val_loss: 1.1362 - val_accuracy: 0.6291
# Epoch 13/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.7306 - accuracy: 0.7373 - val_loss: 1.2723 - val_accuracy: 0.5777
# Epoch 14/50
# 100/100 [==============================] - 34s 342ms/step - loss: 0.7018 - accuracy: 0.7476 - val_loss: 1.1298 - val_accuracy: 0.6228
# Epoch 15/50
# 100/100 [==============================] - 34s 343ms/step - loss: 0.6678 - accuracy: 0.7678 - val_loss: 1.1538 - val_accuracy: 0.6253
# Epoch 16/50
# 100/100 [==============================] - 35s 345ms/step - loss: 0.6399 - accuracy: 0.7709 - val_loss: 1.1370 - val_accuracy: 0.6266
# Epoch 17/50
# 100/100 [==============================] - 35s 347ms/step - loss: 0.6197 - accuracy: 0.7822 - val_loss: 1.1854 - val_accuracy: 0.6115
# Epoch 18/50
# 100/100 [==============================] - 34s 342ms/step - loss: 0.5829 - accuracy: 0.7982 - val_loss: 1.0871 - val_accuracy: 0.6516
# Epoch 19/50
# 100/100 [==============================] - 34s 343ms/step - loss: 0.5334 - accuracy: 0.8074 - val_loss: 1.2865 - val_accuracy: 0.6015
# Epoch 20/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.5447 - accuracy: 0.8052 - val_loss: 1.0845 - val_accuracy: 0.6378
# Epoch 21/50
# 100/100 [==============================] - 34s 342ms/step - loss: 0.5050 - accuracy: 0.8206 - val_loss: 1.2561 - val_accuracy: 0.5927
# Epoch 22/50
# 100/100 [==============================] - 34s 343ms/step - loss: 0.4845 - accuracy: 0.8278 - val_loss: 1.0764 - val_accuracy: 0.6566
# Epoch 23/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.4996 - accuracy: 0.8187 - val_loss: 1.0617 - val_accuracy: 0.6617
# Epoch 24/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.4241 - accuracy: 0.8520 - val_loss: 1.2467 - val_accuracy: 0.6053
# Epoch 25/50
# 100/100 [==============================] - 35s 346ms/step - loss: 0.4358 - accuracy: 0.8404 - val_loss: 1.3085 - val_accuracy: 0.6303
# Epoch 26/50
# 100/100 [==============================] - 35s 348ms/step - loss: 0.3895 - accuracy: 0.8608 - val_loss: 1.1859 - val_accuracy: 0.6441
# Epoch 27/50
# 100/100 [==============================] - 34s 345ms/step - loss: 0.3645 - accuracy: 0.8702 - val_loss: 1.3663 - val_accuracy: 0.6291
# Epoch 28/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.3382 - accuracy: 0.8815 - val_loss: 1.3314 - val_accuracy: 0.6078
# Epoch 29/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.3575 - accuracy: 0.8699 - val_loss: 1.2147 - val_accuracy: 0.6491
# Epoch 30/50
# 100/100 [==============================] - 34s 345ms/step - loss: 0.3232 - accuracy: 0.8837 - val_loss: 1.3071 - val_accuracy: 0.6316
# Epoch 31/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.3100 - accuracy: 0.8900 - val_loss: 1.4049 - val_accuracy: 0.6115
# Epoch 32/50
# 100/100 [==============================] - 34s 345ms/step - loss: 0.3127 - accuracy: 0.8900 - val_loss: 1.2248 - val_accuracy: 0.6529
# Epoch 33/50
# 100/100 [==============================] - 34s 343ms/step - loss: 0.2843 - accuracy: 0.8969 - val_loss: 1.2267 - val_accuracy: 0.6617
# Epoch 34/50
# 100/100 [==============================] - 35s 347ms/step - loss: 0.2654 - accuracy: 0.9054 - val_loss: 1.3399 - val_accuracy: 0.6541
# Epoch 35/50
# 100/100 [==============================] - 35s 346ms/step - loss: 0.2773 - accuracy: 0.8988 - val_loss: 1.2661 - val_accuracy: 0.6454
# Epoch 36/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.2571 - accuracy: 0.9079 - val_loss: 1.3577 - val_accuracy: 0.6328
# Epoch 37/50
# 100/100 [==============================] - 34s 343ms/step - loss: 0.2131 - accuracy: 0.9302 - val_loss: 1.4422 - val_accuracy: 0.6404
# Epoch 38/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.2383 - accuracy: 0.9148 - val_loss: 1.2480 - val_accuracy: 0.6441
# Epoch 39/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.2042 - accuracy: 0.9296 - val_loss: 1.5043 - val_accuracy: 0.6216
# Epoch 40/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.2417 - accuracy: 0.9167 - val_loss: 1.3472 - val_accuracy: 0.6642
# Epoch 41/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.2202 - accuracy: 0.9221 - val_loss: 1.3905 - val_accuracy: 0.6429
# Epoch 42/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1970 - accuracy: 0.9327 - val_loss: 1.5634 - val_accuracy: 0.6541
# Epoch 43/50
# 100/100 [==============================] - 35s 348ms/step - loss: 0.1829 - accuracy: 0.9321 - val_loss: 1.4464 - val_accuracy: 0.6404
# Epoch 44/50
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1920 - accuracy: 0.9302 - val_loss: 1.4014 - val_accuracy: 0.6454
# Epoch 45/50
# 100/100 [==============================] - 34s 343ms/step - loss: 0.2174 - accuracy: 0.9202 - val_loss: 1.4804 - val_accuracy: 0.6667
# Epoch 46/50
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1731 - accuracy: 0.9378 - val_loss: 1.5147 - val_accuracy: 0.6642
# Epoch 47/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.1682 - accuracy: 0.9422 - val_loss: 1.6212 - val_accuracy: 0.6378
# Epoch 48/50
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1557 - accuracy: 0.9459 - val_loss: 1.4687 - val_accuracy: 0.6441
# Epoch 49/50
# 100/100 [==============================] - 34s 343ms/step - loss: 0.1587 - accuracy: 0.9453 - val_loss: 1.3515 - val_accuracy: 0.6366
# Epoch 50/50
# 100/100 [==============================] - 34s 345ms/step - loss: 0.1763 - accuracy: 0.9431 - val_loss: 1.4734 - val_accuracy: 0.6491

# %%
plot_train_performance(resume)

# %%
new_model = tf.keras.models.load_model('my_model.h5')
new_model.trainable = True
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# functional_1 (Functional)    (None, 20, 20, 256)       1735488
# _________________________________________________________________
# conv2d (Conv2D)              (None, 20, 20, 512)       3277312
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 20, 512)       4194816
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 512)       6554112
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 512)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 1024)      8389632
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 1024)      26215424
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 10, 10, 1024)      16778240
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 1024)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 25600)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              26215424
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               25700
# =================================================================
# Total params: 94,304,932
# Trainable params: 94,304,932
# Non-trainable params: 0
# _________________________________________________________________

# %%
new_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
resume = new_model.fit(train_data_generator, 
                   validation_data=Validation_data_generator,
                   epochs=epochs)
# Out:
# Epoch 1/50
#   2/100 [..............................] - ETA: 11s - loss: 0.0843 - accuracy: 0.9844WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0756s vs `on_train_batch_end` time: 0.1573s). Check your callbacks.
# 100/100 [==============================] - 39s 389ms/step - loss: 0.1858 - accuracy: 0.9371 - val_loss: 1.3511 - val_accuracy: 0.6629
# Epoch 2/50
# 100/100 [==============================] - 37s 373ms/step - loss: 0.1846 - accuracy: 0.9412 - val_loss: 1.7526 - val_accuracy: 0.6040
# Epoch 3/50
# 100/100 [==============================] - 37s 370ms/step - loss: 0.1626 - accuracy: 0.9453 - val_loss: 1.4975 - val_accuracy: 0.6566
# Epoch 4/50
# 100/100 [==============================] - 37s 371ms/step - loss: 0.1579 - accuracy: 0.9481 - val_loss: 1.4040 - val_accuracy: 0.6654
# Epoch 5/50
# 100/100 [==============================] - 37s 372ms/step - loss: 0.1644 - accuracy: 0.9397 - val_loss: 1.4987 - val_accuracy: 0.6479
# Epoch 6/50
# 100/100 [==============================] - 37s 373ms/step - loss: 0.1328 - accuracy: 0.9544 - val_loss: 1.6191 - val_accuracy: 0.6278
# Epoch 7/50
# 100/100 [==============================] - 37s 371ms/step - loss: 0.1487 - accuracy: 0.9541 - val_loss: 1.5529 - val_accuracy: 0.6504
# Epoch 8/50
# 100/100 [==============================] - 37s 370ms/step - loss: 0.1445 - accuracy: 0.9522 - val_loss: 1.5263 - val_accuracy: 0.6779
# Epoch 9/50
# 100/100 [==============================] - 37s 370ms/step - loss: 0.1288 - accuracy: 0.9525 - val_loss: 1.5464 - val_accuracy: 0.6617
# Epoch 10/50
# 100/100 [==============================] - 37s 373ms/step - loss: 0.1249 - accuracy: 0.9588 - val_loss: 1.3831 - val_accuracy: 0.6554
# Epoch 11/50
# 100/100 [==============================] - 37s 370ms/step - loss: 0.1148 - accuracy: 0.9648 - val_loss: 1.5222 - val_accuracy: 0.6504
# Epoch 12/50
# 100/100 [==============================] - 37s 369ms/step - loss: 0.1461 - accuracy: 0.9551 - val_loss: 1.5249 - val_accuracy: 0.6479
# Epoch 13/50
# 100/100 [==============================] - 37s 371ms/step - loss: 0.1368 - accuracy: 0.9532 - val_loss: 1.3730 - val_accuracy: 0.6830
# Epoch 14/50
# 100/100 [==============================] - 37s 369ms/step - loss: 0.1309 - accuracy: 0.9554 - val_loss: 1.3505 - val_accuracy: 0.6855
# Epoch 15/50
# 100/100 [==============================] - 37s 370ms/step - loss: 0.1076 - accuracy: 0.9632 - val_loss: 1.5009 - val_accuracy: 0.6654
# Epoch 16/50
# 100/100 [==============================] - 37s 369ms/step - loss: 0.1175 - accuracy: 0.9588 - val_loss: 1.5919 - val_accuracy: 0.6667
# Epoch 17/50
# 100/100 [==============================] - 37s 370ms/step - loss: 0.0847 - accuracy: 0.9736 - val_loss: 1.6029 - val_accuracy: 0.6704
# Epoch 18/50
# 100/100 [==============================] - 37s 370ms/step - loss: 0.1008 - accuracy: 0.9670 - val_loss: 1.6982 - val_accuracy: 0.6115
# Epoch 19/50
# 100/100 [==============================] - 37s 371ms/step - loss: 0.1161 - accuracy: 0.9595 - val_loss: 1.6413 - val_accuracy: 0.6378
# Epoch 20/50
# 100/100 [==============================] - 37s 368ms/step - loss: 0.1236 - accuracy: 0.9632 - val_loss: 1.4960 - val_accuracy: 0.6516
# Epoch 21/50
# 100/100 [==============================] - 37s 374ms/step - loss: 0.0942 - accuracy: 0.9689 - val_loss: 1.5925 - val_accuracy: 0.6704
# Epoch 22/50
# 100/100 [==============================] - 37s 371ms/step - loss: 0.1062 - accuracy: 0.9645 - val_loss: 1.7248 - val_accuracy: 0.6103
# Epoch 23/50
# 100/100 [==============================] - 37s 370ms/step - loss: 0.1084 - accuracy: 0.9620 - val_loss: 1.5533 - val_accuracy: 0.6767
# Epoch 24/50
# 100/100 [==============================] - 37s 370ms/step - loss: 0.0894 - accuracy: 0.9698 - val_loss: 1.8196 - val_accuracy: 0.6441
# Epoch 25/50
# 100/100 [==============================] - 37s 370ms/step - loss: 0.1033 - accuracy: 0.9651 - val_loss: 1.5219 - val_accuracy: 0.6604
# Epoch 26/50
# 100/100 [==============================] - 37s 371ms/step - loss: 0.0933 - accuracy: 0.9673 - val_loss: 1.6563 - val_accuracy: 0.6566
# Epoch 27/50
#  38/100 [==========>...................] - ETA: 19s - loss: 0.1036 - accuracy: 0.9649
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-8629e40a3ef3> in <module>()
#       2 resume = new_model.fit(train_data_generator,
#       3                    validation_data=Validation_data_generator,
# ----> 4                    epochs=epochs)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
