# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#from random import shuffle
import glob
import re
import h5py
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline
from sklearn.model_selection import train_test_split 
import pandas as pd
from tensorflow.keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers import LeakyReLU
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras import regularizers
np.set_printoptions(precision=3, suppress=True) #Make numpy easier to read

# %%
os.chdir("/content/drive/My Drive/DeplomadoDeepLearning/Gomez_Saul/Proyecto/")

# %%
ls
# Out:
# 'Copia de ImageClasification_algorithm (1).ipynb'
# 'Copia de ImageClasification_algorithm.ipynb'
#  DataAugmentationOneClass.ipynb
#  DataBase/
#  ImageClasification_algorithm.ipynb
#  ImageSplitManyClasses.ipynb
#  MLP_Clasificador_algorithm.ipynb
#  my_model2.h5
#  my_model.h5
#  OriginalDataBase/
#  Untitled0.ipynb
#  vgg16_block3_ImageClasification_algorithm.ipynb
# 'VGG16_block4_ ImageClasification_algorithm.ipynb'
# ' VGG16_ ImageClasification_algorithm.ipynb'

# %%
train_path = "//content/drive/My Drive/DeplomadoDeepLearning/Gomez_Saul/Proyecto/DataBase/train"
validation_path = "//content/drive/My Drive/DeplomadoDeepLearning/Gomez_Saul/Proyecto/DataBase/validation"

# %%
def trainFileCount(train_path):
  total_file_training= 0;
  basename ='';
  for root, dirnames, filenames in os.walk(train_path):
    for dirname in dirnames:
      directory_training = os.path.join(train_path, dirname) 
      directory_training = directory_training + os.sep
      num_file_training = len(os.listdir(directory_training))
      total_file_training = total_file_training + num_file_training
      basename = os.path.basename(train_path)
      print('total',basename, dirname,' images:',num_file_training)
  print('Total', basename,' images:',total_file_training)
  print('-------------------------------------------------------')

# %%
total_train_img = trainFileCount(train_path)
total_Validation_img = trainFileCount(validation_path)
# Out:
# total train Ptosis  images: 1054
# total train Ectropion  images: 482
# total train Chalazion  images: 218
# total train Triquiasis  images: 163
# total train TumorParpado  images: 368
# total train BlefaroChalasis  images: 581
# total train Blefaritis  images: 132
# total train Xanthelasma  images: 184
# Total train  images: 3182
# -------------------------------------------------------
# total validation Ptosis  images: 264
# total validation Ectropion  images: 121
# total validation Chalazion  images: 55
# total validation Triquiasis  images: 41
# total validation TumorParpado  images: 92
# total validation BlefaroChalasis  images: 146
# total validation Blefaritis  images: 33
# total validation Xanthelasma  images: 46
# Total validation  images: 798
# -------------------------------------------------------

# %%
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
img = cv2.imread('/content/drive/My Drive/DeplomadoDeepLearning/Gomez_Saul/Proyecto/DataBase/train/Blefaritis/1.png')
img.shape
# Out:
# (164, 164, 3)

# %%
batch_size = 32
epochs = 50
IMG_SHAPE = 164

# %%
image_generator_train = ImageDataGenerator(
                    rescale=1./255, 
                    rotation_range=15,
                    width_shift_range=.005, 
                    height_shift_range=.005, 
                    horizontal_flip=True, 
                    zoom_range=0.3
                    )

# %%
image_generator_validation = ImageDataGenerator(
                    rescale=1./255, 
                    rotation_range=20, 
                    width_shift_range=.01, 
                    height_shift_range=.01, 
                    horizontal_flip=True, 
                    zoom_range=0.3
                    )

# %%
train_data_generator = image_generator_train.flow_from_directory(
                                                batch_size=batch_size, 
                                                directory=train_path, 
                                                shuffle=True, 
                                                target_size=(IMG_SHAPE,IMG_SHAPE),
                                                class_mode='binary'
                                                )
# Out:
# Found 3182 images belonging to 8 classes.

# %%
Validation_data_generator = image_generator_validation.flow_from_directory(
                                                batch_size=batch_size, 
                                                directory=validation_path, 
                                                shuffle=False, 
                                                target_size=(IMG_SHAPE,IMG_SHAPE),
                                                class_mode='binary'
                                                )
# Out:
# Found 798 images belonging to 8 classes.

# %%
augmented_images = [train_data_generator[0][0][1] for i in range(5)]

# %%
sample_training_images, _ = next(train_data_generator) 
sample_training_images.shape
# Out:
# (32, 164, 164, 3)

# %%
plotImages(augmented_images[:5])

# %%
# Herramienta para ver el comportamiento del entrenamiento
def plot_train_performance(train_data):
    acc = train_data.history['accuracy']
    val_acc = train_data.history['val_accuracy']
    loss = train_data.history['loss']
    val_loss = train_data.history['val_loss']

    epochs = range(1,len(acc)+1)

    plt.plot(epochs, acc, 'b', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.figure()
    plt.plot(epochs, loss, 'b', label='Training Loss')
    plt.plot(epochs, val_loss, 'r', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    plt.show()

# %%
# Funcion para comparar las predicciónes
import numpy as np
def show_pred(test_ds):
    to_predict_data = test_ds.batch(1).take(9)
    results = np.argmax(model.predict(to_predict_data),axis=1)

    import matplotlib.pyplot as plt # A continuación se muestra un ejemplo con su etiqueta
    fig = plt.figure(figsize=(20,20))
    for i, (image, label) in enumerate(to_predict_data):
      res_plt = fig.add_subplot(3, 3, i+1)
      res_plt.set_title(classes_dict[int(np.squeeze(label.numpy()))])
      predicted_lbl = "Predicted: " + classes_dict[results[i]]
      res_plt.set_xlabel(predicted_lbl)
      plt.imshow(np.squeeze(image.numpy()*255).astype(np.uint8))
    plt.show()

# %%
from tensorflow import keras
from tensorflow.keras.applications.vgg16 import VGG16, decode_predictions 

HEIGHT, WIDTH, CHANNELS = (164,164,3) # el tamaño de las imagenes
input_t = keras.Input(shape=(HEIGHT, WIDTH, CHANNELS)) 
transfer_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_t) # no se incluyen las redes neuronales del final de la aqruitectura

transfer_model.trainable = False # Se congelan los pesos de la arquitectura usada como 
transfer_model.summary() # Se observa la arqutiectura para decidir donnde tomar las caracteristicas
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 164, 164, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 164, 164, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 164, 164, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 82, 82, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 82, 82, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 82, 82, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 41, 41, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 41, 41, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 41, 41, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 41, 41, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 20, 20, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 20, 20, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 10, 10, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 5, 5, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D

model = Sequential()
# Se adicionan la capas empezando por el extractor de características
model.add(transfer_model)
model.add(Flatten())
model.add(Dense(512, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(8, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 5, 5, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               6554112
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 4104
# =================================================================
# Total params: 21,272,904
# Trainable params: 6,558,216
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# # Process examples without training
# for image,label in Validation_data_generator:
#   pred = model(image).numpy()
#   print(pred) # Procesing one example
#   print(pred.shape)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
resume = model.fit(train_data_generator, 
                   validation_data=Validation_data_generator,
                   epochs=epochs)
model.save('my_model.h5')
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1659s 17s/step - loss: 1.6248 - accuracy: 0.4060 - val_loss: 1.3872 - val_accuracy: 0.4912
# Epoch 2/50
# 100/100 [==============================] - 31s 309ms/step - loss: 1.3150 - accuracy: 0.5295 - val_loss: 1.2903 - val_accuracy: 0.5401
# Epoch 3/50
# 100/100 [==============================] - 31s 307ms/step - loss: 1.1985 - accuracy: 0.5691 - val_loss: 1.2615 - val_accuracy: 0.5476
# Epoch 4/50
# 100/100 [==============================] - 31s 308ms/step - loss: 1.1485 - accuracy: 0.5930 - val_loss: 1.2496 - val_accuracy: 0.5714
# Epoch 5/50
# 100/100 [==============================] - 31s 308ms/step - loss: 1.0749 - accuracy: 0.6257 - val_loss: 1.1967 - val_accuracy: 0.5852
# Epoch 6/50
# 100/100 [==============================] - 30s 303ms/step - loss: 1.0324 - accuracy: 0.6370 - val_loss: 1.1962 - val_accuracy: 0.5764
# Epoch 7/50
# 100/100 [==============================] - 31s 305ms/step - loss: 0.9896 - accuracy: 0.6549 - val_loss: 1.2015 - val_accuracy: 0.5627
# Epoch 8/50
# 100/100 [==============================] - 31s 311ms/step - loss: 0.9714 - accuracy: 0.6518 - val_loss: 1.1939 - val_accuracy: 0.5890
# Epoch 9/50
# 100/100 [==============================] - 31s 310ms/step - loss: 0.9422 - accuracy: 0.6628 - val_loss: 1.1807 - val_accuracy: 0.5877
# Epoch 10/50
# 100/100 [==============================] - 31s 306ms/step - loss: 0.9428 - accuracy: 0.6706 - val_loss: 1.1731 - val_accuracy: 0.5764
# Epoch 11/50
# 100/100 [==============================] - 31s 305ms/step - loss: 0.9125 - accuracy: 0.6842 - val_loss: 1.1434 - val_accuracy: 0.6028
# Epoch 12/50
# 100/100 [==============================] - 31s 306ms/step - loss: 0.8611 - accuracy: 0.6980 - val_loss: 1.1584 - val_accuracy: 0.5865
# Epoch 13/50
# 100/100 [==============================] - 30s 303ms/step - loss: 0.8541 - accuracy: 0.6977 - val_loss: 1.1262 - val_accuracy: 0.6053
# Epoch 14/50
# 100/100 [==============================] - 30s 302ms/step - loss: 0.8378 - accuracy: 0.7090 - val_loss: 1.1579 - val_accuracy: 0.6103
# Epoch 15/50
# 100/100 [==============================] - 30s 303ms/step - loss: 0.8368 - accuracy: 0.7106 - val_loss: 1.1274 - val_accuracy: 0.6328
# Epoch 16/50
# 100/100 [==============================] - 30s 299ms/step - loss: 0.8120 - accuracy: 0.7162 - val_loss: 1.1875 - val_accuracy: 0.5965
# Epoch 17/50
# 100/100 [==============================] - 30s 299ms/step - loss: 0.7954 - accuracy: 0.7165 - val_loss: 1.1435 - val_accuracy: 0.5952
# Epoch 18/50
# 100/100 [==============================] - 30s 305ms/step - loss: 0.7861 - accuracy: 0.7313 - val_loss: 1.1869 - val_accuracy: 0.5965
# Epoch 19/50
# 100/100 [==============================] - 30s 301ms/step - loss: 0.7702 - accuracy: 0.7247 - val_loss: 1.1833 - val_accuracy: 0.5915
# Epoch 20/50
# 100/100 [==============================] - 30s 301ms/step - loss: 0.7397 - accuracy: 0.7363 - val_loss: 1.1532 - val_accuracy: 0.6003
# Epoch 21/50
# 100/100 [==============================] - 30s 298ms/step - loss: 0.7354 - accuracy: 0.7404 - val_loss: 1.1416 - val_accuracy: 0.6078
# Epoch 22/50
# 100/100 [==============================] - 30s 299ms/step - loss: 0.7133 - accuracy: 0.7514 - val_loss: 1.1719 - val_accuracy: 0.6103
# Epoch 23/50
# 100/100 [==============================] - 30s 299ms/step - loss: 0.7010 - accuracy: 0.7483 - val_loss: 1.1285 - val_accuracy: 0.6090
# Epoch 24/50
# 100/100 [==============================] - 30s 298ms/step - loss: 0.7057 - accuracy: 0.7489 - val_loss: 1.1606 - val_accuracy: 0.5990
# Epoch 25/50
# 100/100 [==============================] - 30s 299ms/step - loss: 0.6950 - accuracy: 0.7574 - val_loss: 1.1490 - val_accuracy: 0.6078
# Epoch 26/50
# 100/100 [==============================] - 30s 296ms/step - loss: 0.6809 - accuracy: 0.7637 - val_loss: 1.1574 - val_accuracy: 0.6028
# Epoch 27/50
# 100/100 [==============================] - 30s 297ms/step - loss: 0.6597 - accuracy: 0.7706 - val_loss: 1.1468 - val_accuracy: 0.6328
# Epoch 28/50
# 100/100 [==============================] - 30s 303ms/step - loss: 0.6637 - accuracy: 0.7605 - val_loss: 1.1323 - val_accuracy: 0.6228
# Epoch 29/50
# 100/100 [==============================] - 30s 298ms/step - loss: 0.6629 - accuracy: 0.7715 - val_loss: 1.1689 - val_accuracy: 0.6203
# Epoch 30/50
# 100/100 [==============================] - 30s 296ms/step - loss: 0.6311 - accuracy: 0.7816 - val_loss: 1.2117 - val_accuracy: 0.5890
# Epoch 31/50
# 100/100 [==============================] - 30s 297ms/step - loss: 0.6375 - accuracy: 0.7810 - val_loss: 1.1548 - val_accuracy: 0.6140
# Epoch 32/50
# 100/100 [==============================] - 29s 294ms/step - loss: 0.6273 - accuracy: 0.7791 - val_loss: 1.1517 - val_accuracy: 0.6253
# Epoch 33/50
# 100/100 [==============================] - 29s 294ms/step - loss: 0.6307 - accuracy: 0.7854 - val_loss: 1.2063 - val_accuracy: 0.6178
# Epoch 34/50
# 100/100 [==============================] - 29s 293ms/step - loss: 0.6052 - accuracy: 0.7926 - val_loss: 1.2580 - val_accuracy: 0.5940
# Epoch 35/50
# 100/100 [==============================] - 29s 294ms/step - loss: 0.6022 - accuracy: 0.7964 - val_loss: 1.1544 - val_accuracy: 0.6366
# Epoch 36/50
# 100/100 [==============================] - 30s 296ms/step - loss: 0.6002 - accuracy: 0.7894 - val_loss: 1.1777 - val_accuracy: 0.6103
# Epoch 37/50
# 100/100 [==============================] - 29s 295ms/step - loss: 0.5815 - accuracy: 0.8036 - val_loss: 1.1465 - val_accuracy: 0.6291
# Epoch 38/50
# 100/100 [==============================] - 30s 297ms/step - loss: 0.5867 - accuracy: 0.7948 - val_loss: 1.1304 - val_accuracy: 0.6253
# Epoch 39/50
# 100/100 [==============================] - 30s 304ms/step - loss: 0.5591 - accuracy: 0.8014 - val_loss: 1.1600 - val_accuracy: 0.6253
# Epoch 40/50
# 100/100 [==============================] - 29s 294ms/step - loss: 0.5592 - accuracy: 0.8067 - val_loss: 1.2028 - val_accuracy: 0.6090
# Epoch 41/50
# 100/100 [==============================] - 30s 296ms/step - loss: 0.5541 - accuracy: 0.8011 - val_loss: 1.1997 - val_accuracy: 0.6028
# Epoch 42/50
# 100/100 [==============================] - 30s 296ms/step - loss: 0.5470 - accuracy: 0.8011 - val_loss: 1.1738 - val_accuracy: 0.6140
# Epoch 43/50
# 100/100 [==============================] - 30s 297ms/step - loss: 0.5285 - accuracy: 0.8206 - val_loss: 1.2002 - val_accuracy: 0.6140
# Epoch 44/50
# 100/100 [==============================] - 30s 297ms/step - loss: 0.5199 - accuracy: 0.8199 - val_loss: 1.1677 - val_accuracy: 0.6278
# Epoch 45/50
# 100/100 [==============================] - 30s 300ms/step - loss: 0.5235 - accuracy: 0.8155 - val_loss: 1.1965 - val_accuracy: 0.6341
# Epoch 46/50
# 100/100 [==============================] - 30s 296ms/step - loss: 0.5099 - accuracy: 0.8237 - val_loss: 1.1570 - val_accuracy: 0.6341
# Epoch 47/50
# 100/100 [==============================] - 30s 300ms/step - loss: 0.5151 - accuracy: 0.8250 - val_loss: 1.2188 - val_accuracy: 0.6190
# Epoch 48/50
# 100/100 [==============================] - 30s 298ms/step - loss: 0.5135 - accuracy: 0.8212 - val_loss: 1.1801 - val_accuracy: 0.6040
# Epoch 49/50
# 100/100 [==============================] - 31s 306ms/step - loss: 0.5075 - accuracy: 0.8209 - val_loss: 1.2066 - val_accuracy: 0.5990
# Epoch 50/50
# 100/100 [==============================] - 29s 295ms/step - loss: 0.5005 - accuracy: 0.8334 - val_loss: 1.2106 - val_accuracy: 0.6128

# %%
plot_train_performance(resume)

# %%
new_model = tf.keras.models.load_model('my_model.h5')
new_model.trainable = True
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 5, 5, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               6554112
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 4104
# =================================================================
# Total params: 21,272,904
# Trainable params: 21,272,904
# Non-trainable params: 0
# _________________________________________________________________

# %%
new_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
resume = new_model.fit(train_data_generator, 
                   validation_data=Validation_data_generator,
                   epochs=epochs)
# Out:
# Epoch 1/50
#   2/100 [..............................] - ETA: 6s - loss: 0.3903 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0458s vs `on_train_batch_end` time: 0.0814s). Check your callbacks.
# 100/100 [==============================] - 34s 337ms/step - loss: 0.4893 - accuracy: 0.8231 - val_loss: 1.2627 - val_accuracy: 0.6216
# Epoch 2/50
# 100/100 [==============================] - 34s 339ms/step - loss: 0.4268 - accuracy: 0.8532 - val_loss: 1.2481 - val_accuracy: 0.6642
# Epoch 3/50
# 100/100 [==============================] - 35s 348ms/step - loss: 0.3736 - accuracy: 0.8749 - val_loss: 1.2946 - val_accuracy: 0.6353
# Epoch 4/50
# 100/100 [==============================] - 34s 344ms/step - loss: 0.3412 - accuracy: 0.8859 - val_loss: 1.2735 - val_accuracy: 0.6566
# Epoch 5/50
# 100/100 [==============================] - 33s 332ms/step - loss: 0.3133 - accuracy: 0.8884 - val_loss: 1.3974 - val_accuracy: 0.6516
# Epoch 6/50
# 100/100 [==============================] - 33s 331ms/step - loss: 0.2851 - accuracy: 0.8979 - val_loss: 1.4066 - val_accuracy: 0.6554
# Epoch 7/50
# 100/100 [==============================] - 33s 330ms/step - loss: 0.2840 - accuracy: 0.9001 - val_loss: 1.2813 - val_accuracy: 0.6366
# Epoch 8/50
# 100/100 [==============================] - 33s 334ms/step - loss: 0.2648 - accuracy: 0.9104 - val_loss: 1.3788 - val_accuracy: 0.6378
# Epoch 9/50
# 100/100 [==============================] - 33s 332ms/step - loss: 0.2345 - accuracy: 0.9192 - val_loss: 1.4281 - val_accuracy: 0.6341
# Epoch 10/50
# 100/100 [==============================] - 33s 331ms/step - loss: 0.2118 - accuracy: 0.9236 - val_loss: 1.4476 - val_accuracy: 0.6742
# Epoch 11/50
# 100/100 [==============================] - 33s 332ms/step - loss: 0.2086 - accuracy: 0.9255 - val_loss: 1.3341 - val_accuracy: 0.6654
# Epoch 12/50
# 100/100 [==============================] - 33s 330ms/step - loss: 0.2103 - accuracy: 0.9233 - val_loss: 1.5017 - val_accuracy: 0.6491
# Epoch 13/50
# 100/100 [==============================] - 33s 330ms/step - loss: 0.1891 - accuracy: 0.9368 - val_loss: 1.7133 - val_accuracy: 0.6291
# Epoch 14/50
# 100/100 [==============================] - 33s 330ms/step - loss: 0.1614 - accuracy: 0.9415 - val_loss: 1.4598 - val_accuracy: 0.6554
# Epoch 15/50
# 100/100 [==============================] - 33s 329ms/step - loss: 0.1636 - accuracy: 0.9412 - val_loss: 1.4603 - val_accuracy: 0.6654
# Epoch 16/50
# 100/100 [==============================] - 33s 332ms/step - loss: 0.1594 - accuracy: 0.9453 - val_loss: 1.5796 - val_accuracy: 0.6704
# Epoch 17/50
# 100/100 [==============================] - 34s 336ms/step - loss: 0.1604 - accuracy: 0.9478 - val_loss: 1.5872 - val_accuracy: 0.6516
# Epoch 18/50
# 100/100 [==============================] - 33s 335ms/step - loss: 0.1509 - accuracy: 0.9481 - val_loss: 1.5930 - val_accuracy: 0.6579
# Epoch 19/50
# 100/100 [==============================] - 33s 328ms/step - loss: 0.1255 - accuracy: 0.9551 - val_loss: 1.7521 - val_accuracy: 0.6353
# Epoch 20/50
# 100/100 [==============================] - 34s 336ms/step - loss: 0.1427 - accuracy: 0.9519 - val_loss: 1.4377 - val_accuracy: 0.6692
# Epoch 21/50
# 100/100 [==============================] - 33s 334ms/step - loss: 0.1207 - accuracy: 0.9604 - val_loss: 1.5311 - val_accuracy: 0.6692
# Epoch 22/50
# 100/100 [==============================] - 34s 336ms/step - loss: 0.1299 - accuracy: 0.9547 - val_loss: 1.5536 - val_accuracy: 0.6817
# Epoch 23/50
# 100/100 [==============================] - 33s 333ms/step - loss: 0.1142 - accuracy: 0.9648 - val_loss: 1.5264 - val_accuracy: 0.6654
# Epoch 24/50
# 100/100 [==============================] - 33s 330ms/step - loss: 0.1013 - accuracy: 0.9673 - val_loss: 1.6063 - val_accuracy: 0.6642
# Epoch 25/50
# 100/100 [==============================] - 33s 328ms/step - loss: 0.1095 - accuracy: 0.9626 - val_loss: 1.5233 - val_accuracy: 0.6779
# Epoch 26/50
# 100/100 [==============================] - 33s 331ms/step - loss: 0.0970 - accuracy: 0.9654 - val_loss: 1.5970 - val_accuracy: 0.6541
# Epoch 27/50
# 100/100 [==============================] - 33s 335ms/step - loss: 0.1159 - accuracy: 0.9657 - val_loss: 1.5375 - val_accuracy: 0.6704
# Epoch 28/50
# 100/100 [==============================] - 33s 335ms/step - loss: 0.0972 - accuracy: 0.9667 - val_loss: 1.5845 - val_accuracy: 0.6855
# Epoch 29/50
# 100/100 [==============================] - 33s 329ms/step - loss: 0.1125 - accuracy: 0.9604 - val_loss: 1.5905 - val_accuracy: 0.6754
# Epoch 30/50
# 100/100 [==============================] - 33s 329ms/step - loss: 0.0949 - accuracy: 0.9695 - val_loss: 1.9187 - val_accuracy: 0.6303
# Epoch 31/50
# 100/100 [==============================] - 33s 330ms/step - loss: 0.0837 - accuracy: 0.9714 - val_loss: 1.6296 - val_accuracy: 0.6566
# Epoch 32/50
# 100/100 [==============================] - 34s 336ms/step - loss: 0.0879 - accuracy: 0.9701 - val_loss: 1.7442 - val_accuracy: 0.6441
# Epoch 33/50
# 100/100 [==============================] - 33s 332ms/step - loss: 0.0947 - accuracy: 0.9642 - val_loss: 1.5311 - val_accuracy: 0.6667
# Epoch 34/50
# 100/100 [==============================] - 33s 329ms/step - loss: 0.0806 - accuracy: 0.9749 - val_loss: 1.7806 - val_accuracy: 0.6604
# Epoch 35/50
# 100/100 [==============================] - 33s 330ms/step - loss: 0.0706 - accuracy: 0.9745 - val_loss: 1.6463 - val_accuracy: 0.6554
# Epoch 36/50
# 100/100 [==============================] - 34s 336ms/step - loss: 0.0892 - accuracy: 0.9676 - val_loss: 1.6017 - val_accuracy: 0.6729
# Epoch 37/50
# 100/100 [==============================] - 33s 331ms/step - loss: 0.0810 - accuracy: 0.9749 - val_loss: 1.7201 - val_accuracy: 0.6504
# Epoch 38/50
# 100/100 [==============================] - 34s 337ms/step - loss: 0.0659 - accuracy: 0.9793 - val_loss: 1.8873 - val_accuracy: 0.6754
# Epoch 39/50
# 100/100 [==============================] - 33s 329ms/step - loss: 0.0838 - accuracy: 0.9714 - val_loss: 1.6803 - val_accuracy: 0.6767
# Epoch 40/50
# 100/100 [==============================] - 33s 335ms/step - loss: 0.0627 - accuracy: 0.9774 - val_loss: 1.6978 - val_accuracy: 0.6880
# Epoch 41/50
# 100/100 [==============================] - 33s 333ms/step - loss: 0.0827 - accuracy: 0.9711 - val_loss: 1.5911 - val_accuracy: 0.6704
# Epoch 42/50
# 100/100 [==============================] - 33s 327ms/step - loss: 0.0813 - accuracy: 0.9698 - val_loss: 1.6881 - val_accuracy: 0.6779
# Epoch 43/50
# 100/100 [==============================] - 33s 330ms/step - loss: 0.0638 - accuracy: 0.9783 - val_loss: 1.6763 - val_accuracy: 0.6805
# Epoch 44/50
# 100/100 [==============================] - 33s 330ms/step - loss: 0.0664 - accuracy: 0.9789 - val_loss: 1.6778 - val_accuracy: 0.6779
# Epoch 45/50
# 100/100 [==============================] - 33s 334ms/step - loss: 0.0719 - accuracy: 0.9749 - val_loss: 1.5358 - val_accuracy: 0.6842
# Epoch 46/50
# 100/100 [==============================] - 33s 327ms/step - loss: 0.0742 - accuracy: 0.9717 - val_loss: 1.6572 - val_accuracy: 0.6967
# Epoch 47/50
# 100/100 [==============================] - 33s 328ms/step - loss: 0.0587 - accuracy: 0.9793 - val_loss: 1.6971 - val_accuracy: 0.6754
# Epoch 48/50
# 100/100 [==============================] - 33s 329ms/step - loss: 0.0627 - accuracy: 0.9774 - val_loss: 1.6292 - val_accuracy: 0.6604
# Epoch 49/50
# 100/100 [==============================] - 33s 328ms/step - loss: 0.0508 - accuracy: 0.9833 - val_loss: 1.8794 - val_accuracy: 0.6742
# Epoch 50/50
# 100/100 [==============================] - 33s 331ms/step - loss: 0.0687 - accuracy: 0.9755 - val_loss: 1.9921 - val_accuracy: 0.6541

# %%
show_pred(Validation_data_generator)
